# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
protein_order = ["WT", "H191E","K237R"]
protein_colors_dict = {
    "WT": "lightgrey",
    "H191E": "#A0AABA",
    "K237R": "#E35336"
}
kin_data_57 = pd.read_excel("data/kinetics_parameters_57.xlsx")

# %%
fig, axes = plt.subplots(ncols=3, figsize=(12, 5))
axes[0].bar(
    kin_data_57["Protein"], 
    kin_data_57["kcat avg"], 
    yerr=kin_data_57["kcat stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
axes[1].bar(
    kin_data_57["Protein"], 
    kin_data_57["km avg"], 
    yerr=kin_data_57["km stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
axes[2].bar(
    kin_data_57["Protein"], 
    kin_data_57["kcat/kM avg"], 
    yerr=kin_data_57["kcat/kM stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
for ax, ylabel in zip(axes, [r'K$_\mathrm{cat}$ (min$^{-1}$)', r'K$_\mathrm{m}$ (µM)', r'K$_\mathrm{cat}$/K$_\mathrm{m}$ (min$^{-1}$ µM$^{-1}$)']):
    ax.set_ylabel(ylabel, fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(ncols=2, figsize=(8, 5))
axes[0].bar(
    kin_data_57["Protein"], 
    kin_data_57["kcat avg"], 
    yerr=kin_data_57["kcat stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
axes[1].bar(
    kin_data_57["Protein"], 
    kin_data_57["km avg"], 
    yerr=kin_data_57["km stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
for ax, ylabel in zip(axes, [r'K$_\mathrm{cat}$ (min$^{-1}$)', r'K$_\mathrm{m}$ (µM)']):
    ax.set_ylabel(ylabel, fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(ncols=1, figsize=(4, 5))
axes.bar(
    kin_data_57["Protein"], 
    kin_data_57["kcat/kM avg"], 
    yerr=kin_data_57["kcat/kM stdev"], 
    capsize=5, 
    edgecolor="black", 
    linewidth=1.0,
    color=[protein_colors_dict[prot] for prot in kin_data_57["Protein"]]
)
axes.set_ylabel(r'K$_\mathrm{cat}$/K$_\mathrm{m}$ (min$^{-1}$ µM$^{-1}$)', fontsize=20)
axes.tick_params(axis='both', which='major', labelsize=15)
axes.set_xlabel("Variant", fontsize=20)
#plt.tight_layout()
plt.show()
